# %% [markdown]
# # Allstate Claims Severity

# %% [markdown]
# ## Initialization

# %%
import pandas as pd
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.grid_search import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ## Data preparation

# %%
train = pd.read_csv('../data/train.csv')
test = pd.read_csv('../data/test.csv')
sample = pd.read_csv('../data/sample_submission.csv')

# %%
train.head()
# Out:
#    id cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9   ...        cont6  \
# 0   1    A    B    A    B    A    A    A    A    B   ...     0.718367
# 1   2    A    B    A    A    A    A    A    A    B   ...     0.438917
# 2   5    A    B    A    A    B    A    A    A    B   ...     0.289648
# 3  10    B    B    A    B    A    A    A    A    B   ...     0.440945
# 4  11    A    B    A    B    A    A    A    A    B   ...     0.178193
#
#       cont7    cont8    cont9   cont10    cont11    cont12    cont13  \
# 0  0.335060  0.30260  0.67135  0.83510  0.569745  0.594646  0.822493
# 1  0.436585  0.60087  0.35127  0.43919  0.338312  0.366307  0.611431
# 2  0.315545  0.27320  0.26076  0.32446  0.381398  0.373424  0.195709
# 3  0.391128  0.31796  0.32128  0.44467  0.327915  0.321570  0.605077
# 4  0.247408  0.24564  0.22089  0.21230  0.204687  0.202213  0.246011
#
#      cont14     loss
# 0  0.714843  2213.18
# 1  0.304496  1283.60
# 2  0.774425  3005.09
# 3  0.602642   939.85
# 4  0.432606  2763.85
#
# [5 rows x 132 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188318 entries, 0 to 188317
# Columns: 132 entries, id to loss
# dtypes: float64(15), int64(1), object(116)
# memory usage: 189.7+ MB

# %%
train.columns
# Out:
# Index(['id', 'cat1', 'cat2', 'cat3', 'cat4', 'cat5', 'cat6', 'cat7', 'cat8',
#        'cat9',
#        ...
#        'cont6', 'cont7', 'cont8', 'cont9', 'cont10', 'cont11', 'cont12',
#        'cont13', 'cont14', 'loss'],
#       dtype='object', length=132)

# %%
test.head()
# Out:
#    id cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9    ...        cont5  \
# 0   4    A    B    A    A    A    A    A    A    B    ...     0.281143
# 1   6    A    B    A    B    A    A    A    A    B    ...     0.836443
# 2   9    A    B    A    B    B    A    B    A    B    ...     0.718531
# 3  12    A    A    A    A    B    A    A    A    A    ...     0.397069
# 4  15    B    A    A    A    A    B    A    A    A    ...     0.302678
#
#       cont6     cont7    cont8    cont9   cont10    cont11    cont12  \
# 0  0.466591  0.317681  0.61229  0.34365  0.38016  0.377724  0.369858
# 1  0.482425  0.443760  0.71330  0.51890  0.60401  0.689039  0.675759
# 2  0.212308  0.325779  0.29758  0.34365  0.30529  0.245410  0.241676
# 3  0.369930  0.342355  0.40028  0.33237  0.31480  0.348867  0.341872
# 4  0.398862  0.391833  0.23688  0.43731  0.50556  0.359572  0.352251
#
#      cont13    cont14
# 0  0.704052  0.392562
# 1  0.453468  0.208045
# 2  0.258586  0.297232
# 3  0.592264  0.555955
# 4  0.301535  0.825823
#
# [5 rows x 131 columns]

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125546 entries, 0 to 125545
# Columns: 131 entries, id to cont14
# dtypes: float64(14), int64(1), object(116)
# memory usage: 125.5+ MB

# %%
test.columns
# Out:
# Index(['id', 'cat1', 'cat2', 'cat3', 'cat4', 'cat5', 'cat6', 'cat7', 'cat8',
#        'cat9',
#        ...
#        'cont5', 'cont6', 'cont7', 'cont8', 'cont9', 'cont10', 'cont11',
#        'cont12', 'cont13', 'cont14'],
#       dtype='object', length=131)

# %%
train.cat5.value_counts()
# Out:
# A    123737
# B     64581
# Name: cat5, dtype: int64

# %%
sample.head()
# Out:
#    id  loss
# 0   4     0
# 1   6     0
# 2   9     0
# 3  12     0
# 4  15     0

# %%
[train[w].value_counts() for w in train]
# Out:
# [550437    1
#  251600    1
#  210636    1
#  200395    1
#  204489    1
#  224967    1
#  312608    1
#  489156    1
#  483009    1
#  218816    1
#  409747    1
#  577697    1
#  310973    1
#  46780     1
#  36539     1
#  269627    1
#  38584     1
#  321206    1
#  268981    1
#  315059    1
#  313010    1
#  474829    1
#  489575    1
#  565169    1
#  509650    1
#  285066    1
#  132842    1
#  138985    1
#  453107    1
#  159463    1
#           ..
#  305984    1
#  457316    1
#  213821    1
#  409340    1
#  228154    1
#  484153    1
#  326229    1
#  262997    1
#  6998      1
#  4951      1
#  101220    1
#  334441    1
#  540768    1
#  117612    1
#  127851    1
#  123753    1
#  560134    1
#  542817    1
#  361317    1
#  111459    1
#  289624    1
#  369505    1
#  371552    1
#  21343     1
#  419575    1
#  17245     1
#  281436    1
#  29531     1
#  31578     1
#  414301    1
#  Name: id, dtype: int64, A    141550
#  B     46768
#  Name: cat1, dtype: int64, A    106721
#  B     81597
#  Name: cat2, dtype: int64, A    177993
#  B     10325
#  Name: cat3, dtype: int64, A    128395
#  B     59923
#  Name: cat4, dtype: int64, A    123737
#  B     64581
#  Name: cat5, dtype: int64, A    131693
#  B     56625
#  Name: cat6, dtype: int64, A    183744
#  B      4574
#  Name: cat7, dtype: int64, A    177274
#  B     11044
#  Name: cat8, dtype: int64, A    113122
#  B     75196
#  Name: cat9, dtype: int64, A    160213
#  B     28105
#  Name: cat10, dtype: int64, A    168186
#  B     20132
#  Name: cat11, dtype: int64, A    159825
#  B     28493
#  Name: cat12, dtype: int64, A    168851
#  B     19467
#  Name: cat13, dtype: int64, A    186041
#  B      2277
#  Name: cat14, dtype: int64, A    188284
#  B        34
#  Name: cat15, dtype: int64, A    181843
#  B      6475
#  Name: cat16, dtype: int64, A    187009
#  B      1309
#  Name: cat17, dtype: int64, A    187331
#  B       987
#  Name: cat18, dtype: int64, A    186510
#  B      1808
#  Name: cat19, dtype: int64, A    188114
#  B       204
#  Name: cat20, dtype: int64, A    187905
#  B       413
#  Name: cat21, dtype: int64, A    188275
#  B        43
#  Name: cat22, dtype: int64, A    157445
#  B     30873
#  Name: cat23, dtype: int64, A    181977
#  B      6341
#  Name: cat24, dtype: int64, A    169969
#  B     18349
#  Name: cat25, dtype: int64, A    177119
#  B     11199
#  Name: cat26, dtype: int64, A    168250
#  B     20068
#  Name: cat27, dtype: int64, A    180938
#  B      7380
#  Name: cat28, dtype: int64, A    184593
#  B      3725
#  Name: cat29, dtype: int64, A    184760
#  B      3558
#  Name: cat30, dtype: int64, A    182980
#  B      5338
#  Name: cat31, dtype: int64, A    187107
#  B      1211
#  Name: cat32, dtype: int64, A    187361
#  B       957
#  Name: cat33, dtype: int64, A    187734
#  B       584
#  Name: cat34, dtype: int64, A    188105
#  B       213
#  Name: cat35, dtype: int64, A    156313
#  B     32005
#  Name: cat36, dtype: int64, A    165729
#  B     22589
#  Name: cat37, dtype: int64, A    169323
#  B     18995
#  Name: cat38, dtype: int64, A    183393
#  B      4925
#  Name: cat39, dtype: int64, A    180119
#  B      8199
#  Name: cat40, dtype: int64, A    181177
#  B      7141
#  Name: cat41, dtype: int64, A    186623
#  B      1695
#  Name: cat42, dtype: int64, A    184110
#  B      4208
#  Name: cat43, dtype: int64, A    172716
#  B     15602
#  Name: cat44, dtype: int64, A    183991
#  B      4327
#  Name: cat45, dtype: int64, A    187436
#  B       882
#  Name: cat46, dtype: int64, A    187617
#  B       701
#  Name: cat47, dtype: int64, A    188049
#  B       269
#  Name: cat48, dtype: int64, A    179127
#  B      9191
#  Name: cat49, dtype: int64, A    137611
#  B     50707
#  Name: cat50, dtype: int64, A    187071
#  B      1247
#  Name: cat51, dtype: int64, A    179505
#  B      8813
#  Name: cat52, dtype: int64, A    172949
#  B     15369
#  Name: cat53, dtype: int64, A    183762
#  B      4556
#  Name: cat54, dtype: int64, A    188173
#  B       145
#  Name: cat55, dtype: int64, A    188136
#  B       182
#  Name: cat56, dtype: int64, A    185296
#  B      3022
#  Name: cat57, dtype: int64, A    188079
#  B       239
#  Name: cat58, dtype: int64, A    188018
#  B       300
#  Name: cat59, dtype: int64, A    187872
#  B       446
#  Name: cat60, dtype: int64, A    187596
#  B       722
#  Name: cat61, dtype: int64, A    188273
#  B        45
#  Name: cat62, dtype: int64, A    188239
#  B        79
#  Name: cat63, dtype: int64, A    188271
#  B        47
#  Name: cat64, dtype: int64, A    186056
#  B      2262
#  Name: cat65, dtype: int64, A    179982
#  B      8336
#  Name: cat66, dtype: int64, A    187626
#  B       692
#  Name: cat67, dtype: int64, A    188176
#  B       142
#  Name: cat68, dtype: int64, A    188011
#  B       307
#  Name: cat69, dtype: int64, A    188295
#  B        23
#  Name: cat70, dtype: int64, A    178646
#  B      9672
#  Name: cat71, dtype: int64, A    118322
#  B     69996
#  Name: cat72, dtype: int64, A    154275
#  B     34017
#  C        26
#  Name: cat73, dtype: int64, A    184731
#  B      3561
#  C        26
#  Name: cat74, dtype: int64, A    154307
#  B     34010
#  C         1
#  Name: cat75, dtype: int64, A    181347
#  B      6183
#  C       788
#  Name: cat76, dtype: int64, D    187503
#  C       408
#  B       358
#  A        49
#  Name: cat77, dtype: int64, B    186526
#  A       788
#  C       645
#  D       359
#  Name: cat78, dtype: int64, B    152929
#  D     26657
#  A      7064
#  C      1668
#  Name: cat79, dtype: int64, D    137505
#  B     46538
#  C      3492
#  A       783
#  Name: cat80, dtype: int64, D    154385
#  B     24132
#  C      9013
#  A       788
#  Name: cat81, dtype: int64, B    147536
#  A     19322
#  D     18805
#  C      2655
#  Name: cat82, dtype: int64, B    141534
#  A     26038
#  D     15788
#  C      4958
#  Name: cat83, dtype: int64, C    154939
#  A     29450
#  D      3498
#  B       431
#  Name: cat84, dtype: int64, B    186005
#  C      1011
#  A       788
#  D       514
#  Name: cat85, dtype: int64, B    103852
#  D     72587
#  C     10290
#  A      1589
#  Name: cat86, dtype: int64, B    166992
#  D     11719
#  C      8819
#  A       788
#  Name: cat87, dtype: int64, A    168926
#  D     19302
#  E        83
#  B         7
#  Name: cat88, dtype: int64, A    183744
#  B      4312
#  C       220
#  D        33
#  E         5
#  I         2
#  H         1
#  G         1
#  Name: cat89, dtype: int64, A    177993
#  B      9515
#  C       728
#  D        70
#  E         6
#  F         4
#  G         2
#  Name: cat90, dtype: int64, A    111028
#  B     42630
#  G     26734
#  C      6400
#  D      1149
#  E       254
#  F        97
#  H        26
#  Name: cat91, dtype: int64, A    124689
#  H     62901
#  B       628
#  C        62
#  I        26
#  D        11
#  F         1
#  Name: cat92, dtype: int64, D    150237
#  C     35788
#  B      1133
#  E       728
#  A       432
#  Name: cat93, dtype: int64, D    121642
#  B     51710
#  C     13623
#  A       738
#  F       494
#  E        91
#  G        20
#  Name: cat94, dtype: int64, C    87531
#  D    79525
#  E    17417
#  A     3736
#  B      109
#  Name: cat95, dtype: int64, E    174360
#  D      7922
#  B      2957
#  G      2665
#  F       343
#  A        35
#  C        24
#  I        12
#  Name: cat96, dtype: int64, C    78127
#  E    47450
#  A    41970
#  G    16745
#  D     3779
#  F      213
#  B       34
#  Name: cat97, dtype: int64, A    105492
#  D     50557
#  C     21485
#  E     10242
#  B       542
#  Name: cat98, dtype: int64, P    79455
#  T    72591
#  R    10290
#  D     8844
#  S     7045
#  N     2894
#  K     2703
#  F     2702
#  E     1034
#  C      310
#  J      245
#  H       93
#  M       52
#  I       38
#  G       19
#  O        3
#  Name: cat99, dtype: int64, F    42970
#  I    39933
#  L    19961
#  K    13817
#  G    12935
#  J    12027
#  H    10776
#  A     9402
#  N     7592
#  B     6608
#  O     5697
#  M     5185
#  C      836
#  D      553
#  E       26
#  Name: cat100, dtype: int64, A    106721
#  D     17171
#  C     16971
#  G     10944
#  F     10139
#  J      7259
#  I      6690
#  M      3669
#  L      3173
#  Q      2762
#  O      2493
#  S       173
#  R       138
#  E         7
#  B         3
#  K         2
#  H         1
#  N         1
#  U         1
#  Name: cat101, dtype: int64, A    177274
#  B      5155
#  C      4929
#  E       482
#  D       449
#  G        15
#  F        12
#  H         1
#  J         1
#  Name: cat102, dtype: int64, A    123737
#  B     33342
#  C     16508
#  D      7806
#  E      4473
#  F      1528
#  G       550
#  H       190
#  I       109
#  J        45
#  L        17
#  K        11
#  N         2
#  Name: cat103, dtype: int64, E    42925
#  G    40660
#  D    27611
#  F    19228
#  H    17187
#  K    14297
#  I    10919
#  C     6949
#  L     3486
#  J     3138
#  M     1156
#  O      409
#  N      153
#  P       86
#  A       68
#  B       43
#  Q        3
#  Name: cat104, dtype: int64, E    76493
#  F    62892
#  G    20613
#  D    12172
#  H    11258
#  I     2941
#  J      694
#  K      486
#  C      275
#  M      171
#  L      145
#  A       77
#  N       64
#  P       15
#  O        9
#  B        5
#  Q        4
#  R        2
#  S        1
#  T        1
#  Name: cat105, dtype: int64, G    47165
#  H    37713
#  F    36143
#  I    21433
#  J    18281
#  E    13000
#  K     7958
#  L     2971
#  D     1934
#  M     1176
#  N      231
#  C      129
#  A       75
#  O       66
#  R       32
#  B        9
#  P        2
#  Name: cat106, dtype: int64, F    47310
#  G    28560
#  H    23461
#  J    22405
#  K    20236
#  I    20066
#  E    12521
#  L     6976
#  D     3225
#  M     2067
#  N      797
#  C      213
#  Q      140
#  O      125
#  P      100
#  A       75
#  U       32
#  R        5
#  B        2
#  S        2
#  Name: cat107, dtype: int64, B    65512
#  K    42435
#  G    21421
#  D    19160
#  F    10242
#  A     9299
#  E     7968
#  I     7243
#  H     4305
#  C      520
#  J      213
#  Name: cat108, dtype: int64, BI    152918
#  AB     21933
#  BU      3142
#  K       2999
#  G       1353
#  BQ      1067
#  N        461
#  M        446
#  BO       329
#  BH       257
#  D        214
#  AR       208
#  AT       200
#  CL       178
#  AS       159
#  AL       151
#  R        149
#  CD       143
#  F        124
#  BL       122
#  CI       109
#  I         94
#  L         89
#  U         78
#  AW        74
#  H         73
#  CA        66
#  Q         66
#  BX        61
#  T         59
#         ...
#  BC        14
#  CK        13
#  CF        12
#  V         11
#  BS         9
#  AY         9
#  CJ         8
#  CE         8
#  P          8
#  CG         8
#  AF         8
#  AP         7
#  CH         6
#  AV         6
#  BE         5
#  BY         3
#  BG         3
#  BN         2
#  BV         2
#  BM         2
#  AO         2
#  BT         2
#  BF         1
#  AG         1
#  BP         1
#  AK         1
#  B          1
#  J          1
#  ZZ         1
#  CB         1
#  Name: cat109, dtype: int64, CL    25305
#  EG    24654
#  CS    24592
#  EB    21396
#  CO    17495
#  BT    16365
#  EL     9236
#  BC     4131
#  DW     3640
#  CQ     3271
#  DX     3096
#  AI     2965
#  BP     2867
#  W      2703
#  C      2681
#  AC     2611
#  CM     1925
#  BS     1920
#  DK     1745
#  V      1692
#  A      1296
#  EE     1185
#  EF     1159
#  CI     1066
#  DM      796
#  CR      767
#  AM      643
#  AD      626
#  AP      576
#  T       529
#        ...
#  CD        8
#  ED        8
#  H         8
#  AG        7
#  BB        6
#  CX        6
#  BU        4
#  DB        4
#  AH        4
#  EK        4
#  Q         3
#  DD        3
#  AF        3
#  AN        3
#  DT        3
#  EI        2
#  BN        2
#  CU        2
#  BV        2
#  DN        2
#  EJ        2
#  BM        1
#  AS        1
#  CB        1
#  DV        1
#  BK        1
#  BD        1
#  S         1
#  EH        1
#  BI        1
#  Name: cat110, dtype: int64, A    128395
#  C     32401
#  E     14682
#  G      7039
#  I      3578
#  K      1353
#  M       473
#  O       221
#  Q        91
#  S        38
#  W        16
#  U        16
#  B         7
#  F         3
#  D         3
#  Y         2
#  Name: cat111, dtype: int64, E     25148
#  AH    18639
#  AS    17669
#  J     16222
#  AF     9368
#  AN     9138
#  N      8453
#  U      8356
#  AV     7122
#  AK     6726
#  K      6059
#  AI     4749
#  S      4201
#  AP     4000
#  G      3168
#  F      3149
#  AW     3145
#  A      2411
#  AR     2365
#  C      2257
#  O      2183
#  D      1645
#  AD     1531
#  AY     1414
#  Y      1351
#  AG     1331
#  AT     1272
#  AA     1241
#  AM     1170
#  AL     1130
#  R      1123
#  AX     1074
#  I       940
#  X       925
#  AE      834
#  Q       793
#  V       693
#  H       548
#  AO      534
#  T       521
#  L       493
#  W       461
#  AC      454
#  M       439
#  AU      434
#  B       423
#  P       406
#  AB      246
#  BA      190
#  AJ      144
#  AQ       30
#  Name: cat112, dtype: int64, BM    26191
#  AE    22030
#  L     13058
#  AX    12661
#  Y     11374
#  K      7738
#  S      7033
#  X      7016
#  AF     6079
#  AN     5214
#  H      5094
#  AT     4664
#  AJ     4425
#  AD     4419
#  AS     3901
#  AK     3520
#  BN     3486
#  I      3279
#  A      3269
#  J      3105
#  N      2839
#  BC     2793
#  Q      2784
#  BJ     2605
#  M      2485
#  AG     2415
#  AW     1825
#  BG     1804
#  AU     1630
#  AO     1628
#        ...
#  BO     1413
#  BH     1221
#  BK      693
#  AV      528
#  AY      466
#  AM      450
#  AI      440
#  BF      347
#  BD      337
#  AH      209
#  C       143
#  BB       53
#  BA       42
#  BI       32
#  G        18
#  AB       18
#  AQ       17
#  V        15
#  U        11
#  O        10
#  E         7
#  AP        6
#  BE        3
#  AL        3
#  BL        3
#  T         2
#  AR        1
#  P         1
#  AC        1
#  B         1
#  Name: cat113, dtype: int64, A    131693
#  C     16793
#  E     16475
#  J      8199
#  F      7905
#  N      2455
#  I      2432
#  R       912
#  L       870
#  U       250
#  O       240
#  Q        43
#  V        33
#  B         6
#  D         5
#  S         4
#  X         1
#  W         1
#  G         1
#  Name: cat114, dtype: int64, K    43866
#  O    26813
#  J    23895
#  N    22438
#  P    21538
#  L    16125
#  M    12444
#  Q     8258
#  I     7090
#  H     2793
#  R     2038
#  G      315
#  F      269
#  S      250
#  A       75
#  T       56
#  U       26
#  E       11
#  W        6
#  X        5
#  D        4
#  B        2
#  C        1
#  Name: cat115, dtype: int64, HK    21061
#  DJ    20244
#  CK    10162
#  DP     9202
#  GS     8736
#  CR     6862
#  HX     5629
#  DC     4557
#  HG     4414
#  IE     4225
#  HQ     4044
#  HV     3853
#  GC     3803
#  LM     3277
#  LB     3194
#  LN     3127
#  KW     3085
#  HJ     2741
#  GK     2632
#  DF     2519
#  IG     2269
#  LO     2082
#  HB     2007
#  MD     1960
#  CB     1909
#  LF     1873
#  GI     1835
#  BY     1620
#  KC     1513
#  GE     1399
#        ...
#  JO        1
#  HO        1
#  JT        1
#  JA        1
#  AR        1
#  AH        1
#  FI        1
#  AP        1
#  FO        1
#  AS        1
#  BF        1
#  JN        1
#  MH        1
#  DQ        1
#  KH        1
#  MS        1
#  BG        1
#  FM        1
#  MT        1
#  FS        1
#  AM        1
#  BI        1
#  IX        1
#  KS        1
#  DY        1
#  JI        1
#  EQ        1
#  JD        1
#  AT        1
#  FP        1
#  Name: cat116, dtype: int64, 0.475784    5862
#  0.503312    3257
#  0.325401    2980
#  0.546670    2902
#  0.330514    2742
#  0.484469    2706
#  0.480125    2550
#  0.894333    2261
#  0.465671    2083
#  0.629339    2061
#  0.513457    1996
#  0.458463    1901
#  0.603582    101
#  0.808858    101
#  0.822889    100
#  0.237824     98
#  0.297801     98
#  0.221048     97
#  0.801204     96
#             ...
#  0.283153      1
#  0.183895      1
#  0.727750      1
#  0.820011      1
#  0.746864      1
#  0.727036      1
#  0.812255      1
#  0.827704      1
#  0.261999      1
#  0.641634      1
#  0.324779      1
#  0.187880      1
#  0.373399      1
#  0.381316      1
#  0.394683      1
#  0.383721      1
#  0.355821      1
#  0.814264      1
#  0.392075      1
#  0.263790      1
#  0.204451      1
#  0.835777      1
#  0.275411      1
#  0.365376      1
#  0.483366      1
#  0.814401      1
#  0.606913      1
#  0.254108      1
#  0.724642      1
#  0.837082      1
#  Name: cont14, dtype: int64, 580.00      104
#  1080.00      26
#  330.00       18
#  700.00       13
#  280.00       13
#  800.00       10
#  300.00        9
#  750.00        9
#  480.00        9
#  80.00         9
#  1000.00       8
#  500.00        8
#  660.00        7
#  1086.06       7
#  642.60        6
#  350.00        6
#  960.78        6
#  1337.14       6
#  600.00        6
#  2000.00       6
#  200.00        6
#  980.00        6
#  1288.89       5
#  1173.43       5
#  890.96        5
#  1045.40       5
#  1477.92       5
#  888.64        5
#  1258.30       5
#  710.42        5
#             ...
#  277.45        1
#  6667.85       1
#  667.47        1
#  4369.84       1
#  1143.03       1
#  17658.34      1
#  1047.95       1
#  2362.84       1
#  1730.62       1
#  3193.70       1
#  5446.92       1
#  2886.48       1
#  7804.39       1
#  2804.29       1
#  893.59        1
#  2150.53       1
#  953.02        1
#  4555.76       1
#  1389.96       1
#  1096.26       1
#  807.87        1
#  1338.48       1
#  1968.06       1
#  1780.54       1
#  1446.48       1
#  706.56        1
#  3062.73       1
#  5756.14       1
#  3402.68       1
#  768.00        1
#  Name: loss, dtype: int64]

# %% [markdown]
# Drop

# %%
outcome = train.loss
train.drop(['id', 'loss'], axis=1, inplace=True)
testId = test['id']
test.drop(['id'], axis=1, inplace=True)
train['Test'] = False
test['Test'] = True
data = pd.concat([train, test], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-140-96d5ac114cc2> in <module>()
# ----> 1 outcome = train.loss
#       2 train.drop(['id', 'loss'], axis=1, inplace=True)
#       3 testId = test['id']
#       4 test.drop(['id'], axis=1, inplace=True)
#       5 train['Test'] = False
#
# /Users/Baker/anaconda/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'loss'

# %%
# Out:
#   cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9 cat10  ...   cat107 cat108  \
# 0    A    B    A    B    A    A    A    A    B     A  ...        J      G
# 1    A    B    A    A    A    A    A    A    B     B  ...        K      K
# 2    A    B    A    A    B    A    A    A    B     B  ...        F      A
# 3    B    B    A    B    A    A    A    A    B     A  ...        K      K
# 4    A    B    A    B    A    A    A    A    B     B  ...        G      B
#
#   cat109 cat110 cat111 cat112 cat113 cat114 cat115 cat116
# 0     BU     BC      C     AS      S      A      O     LB
# 1     BI     CQ      A     AV     BM      A      O     DP
# 2     AB     DK      A      C     AF      A      I     GK
# 3     BI     CS      C      N     AE      A      O     DJ
# 4      H      C      C      Y     BM      A      K     CK
#
# [5 rows x 116 columns]

# %%
data = pd.get_dummies(data, columns=data.columns[:116])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-139-8a436ec07713> in <module>()
# ----> 1 data_dummies = pd.get_dummies(data, columns=data.columns[:116])
#
# /Users/Baker/anaconda/lib/python3.5/site-packages/pandas/core/reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first)
#    1097                                     drop_first=drop_first)
#    1098             with_dummies.append(dummy)
# -> 1099         result = concat(with_dummies, axis=1)
#    1100     else:
#    1101         result = _get_dummies_1d(data, prefix, prefix_sep, dummy_na,
#
# /Users/Baker/anaconda/lib/python3.5/site-packages/pandas/tools/merge.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, copy)
#    1324                        verify_integrity=verify_integrity,
#    1325                        copy=copy)
# -> 1326     return op.get_result()
#    1327
#    1328
#
# /Users/Baker/anaconda/lib/python3.5/site-packages/pandas/tools/merge.py in get_result(self)
#    1515             new_data = concatenate_block_managers(
#    1516                 mgrs_indexers, self.new_axes, concat_axis=self.axis,
# -> 1517                 copy=self.copy)
#    1518             if not self.copy:
#    1519                 new_data._consolidate_inplace()
#
# /Users/Baker/anaconda/lib/python3.5/site-packages/pandas/core/internals.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#    4795     blocks = [make_block(
#    4796         concatenate_join_units(join_units, concat_axis, copy=copy),
# -> 4797         placement=placement) for placement, join_units in concat_plan]
#    4798
#    4799     return BlockManager(blocks, axes)
#
# /Users/Baker/anaconda/lib/python3.5/site-packages/pandas/core/internals.py in <listcomp>(.0)
#    4795     blocks = [make_block(
#    4796         concatenate_join_units(join_units, concat_axis, copy=copy),
# -> 4797         placement=placement) for placement, join_units in concat_plan]
#    4798
#    4799     return BlockManager(blocks, axes)
#
# /Users/Baker/anaconda/lib/python3.5/site-packages/pandas/core/internals.py in concatenate_join_units(join_units, concat_axis, copy)
#    4898         concat_values = to_concat[0]
#    4899         if copy and concat_values.base is not None:
# -> 4900             concat_values = concat_values.copy()
#    4901     else:
#    4902         concat_values = _concat._concat_compat(to_concat, axis=concat_axis)
#
# KeyboardInterrupt:

# %%
data.columns
# Out:
# Index(['cont1', 'cont2', 'cont3', 'cont4', 'cont5', 'cont6', 'cont7', 'cont8',
#        'cont9', 'cont10',
#        ...
#        'cat116_P', 'cat116_Q', 'cat116_R', 'cat116_S', 'cat116_T', 'cat116_U',
#        'cat116_V', 'cat116_W', 'cat116_X', 'cat116_Y'],
#       dtype='object', length=1191)

# %% [markdown]
# ## Machine Learning

# %%
train = data[data.Test == 0].drop('Test', axis=1).copy()
test = data[data.Test == 1].drop('Test', axis=1).copy()
del data

# %%
X = train
y = outcome
Xtr, Xval, ytr, yval = train_test_split(X, y, test_size=0.15, random_state=777)

# %%
Xtr.shape, Xval.shape
# Out:
# ((160070, 1190), (28248, 1190))

# %% [markdown]
# ### Linear regression

# %%
lr = LinearRegression()

# %%
lr.fit(Xtr,ytr)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lr_pred_val = lr.predict(Xval)

# %%
lr_mae = mean_absolute_error(yval, lr_pred_val, sample_weight=None, multioutput='uniform_average')

# %%
lr_mae
# Out:
# 16111576285.918974

# %%
#print('Train correct prediction: ', lr.score(Xtr, ytr))
#print('Validation correct prediction: ', lr.score(Xval, yval))

# %%
lr_pred = lr.predict(test)

# %%
lr_submit = pd.DataFrame({'id': testId, 'loss': lr_pred})

# %%
lr_submit.head()
# Out:
#    id     loss
# 0   4   1156.0
# 1   6   2150.0
# 2   9  11316.0
# 3  12   5971.0
# 4  15    237.0

# %%
lr_submit.to_csv('../output/2016-11-11-bff-linear-regression.csv', index=False)

# %% [markdown]
# ### Random forest

# %%
rf1 = RandomForestRegressor(criterion="mae")

# %%
rf = RandomForestRegressor(n_estimators = 100, criterion="mae")

# %%
rf1.fit(Xtr, ytr)

# %%
rf_pred_val = rf.predict(Xval)
